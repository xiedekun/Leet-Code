# %% [markdown]
# ### 99. 恢复二叉搜索树
# 给你二叉搜索树的根节点 root ，该树中的 恰好 两个节点的值被错误地交换。请在不改变其结构的情况下，恢复这棵树 。
#
# 示例 1：
#
# ![image.png](attachment:image.png)
#
# 输入：root = [1,3,null,null,2]
#
# 输出：[3,1,null,null,2]
#
# 解释：3 不能是 1 的左孩子，因为 3 > 1 。交换 1 和 3 使二叉搜索树有效。
#
# https://leetcode.cn/problems/recover-binary-search-tree

# %% [markdown]
# **思路**：中序遍历以搜寻两个异常节点：node1肯定是大于后面不符合，node2肯定是小于前面不符合；需要用pre变量记录前一个节点；最后交换node1和node2的值。

# %%
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
def recoverTree(root):
    """
    :type root: TreeNode
    :rtype: None Do not return anything, modify root in-place instead.
    """
    pre = node1 = node2 = None

    def inorder(node):

        nonlocal pre, node1, node2
        
        if not node:
            return 

        inorder(node.left)

        if pre!=None and pre.val>node.val:
            if not node1:
                node1 = pre #第一个点肯定是大于后面的点不符合
            node2 = node # 第二个点一定是小于前面的点不符合

        pre = node

        inorder(node.right)

    inorder(root)
    node1.val, node2.val = node2.val, node1.val

# %%
node = TreeNode(1,TreeNode(3,None,TreeNode(2)))
node = TreeNode(3,TreeNode(1), TreeNode(4,None, TreeNode(2)))
recoverTree(node)
node.right.val
# Out:
# 2
