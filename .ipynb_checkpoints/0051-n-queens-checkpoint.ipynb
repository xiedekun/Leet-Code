# %% [markdown]
# ### 51. N 皇后
# 按照国际象棋的规则，皇后可以攻击与之处在同一行或同一列或同一斜线上的棋子。
#
# n 皇后问题 研究的是如何将 n 个皇后放置在 n×n 的棋盘上，并且使皇后彼此之间不能相互攻击。
#
# 给你一个整数 n ，返回所有不同的 n 皇后问题 的解决方案。
#
# 每一种解法包含一个不同的 n 皇后问题 的棋子放置方案，该方案中 'Q' 和 '.' 分别代表了皇后和空位。
#
#
#
# 示例 1：
#
# ![image.png](attachment:image.png)
#
# 输入：n = 4
#
# 输出：[[".Q..","...Q","Q...","..Q."],["..Q.","Q...","...Q",".Q.."]]
#
# 解释：如上图所示，4 皇后问题存在两个不同的解法。
#
# https://leetcode.cn/problems/n-queens

# %% [markdown]
# **思路**：关键点：
#
# 必须要满足p+q != x+y 和p-q!= x-y, 前者针对左下右上斜线，后者针对左上右下斜线，两者同时都保证了不在同一条横行和纵行上。

# %%
def solveNQueens(n):
    """
    :type n: int
    :rtype: List[List[str]]
    """

# %%
n = 4
res = []
def backtrack(n, board):
    if len(arr) == n and len(arr[-1])==n:
        res.append(arr)
        return 
    
    for i in range(n):
        for j in range(n):
            if arr:
                s = arr[-1]
            backtrack(n, arr+[])
